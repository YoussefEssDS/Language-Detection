# %%
import os #To manage access to directories from python
import string
import unicodedata
from nltk import ngrams
import pickle
import time
import pandas as pd
import nltk
import operator

# %%
start=time.time()
with open('final_dict','rb') as pickle_in:
    final_dict = pickle.load(pickle_in)
end=time.time()
print(end-start)

# %%
pt_files=final_dict['portuguese']

# %%
del(final_dict) #unbind to release memory

# %%
def generate_ngram(term,n):
    generated_ngrams = ngrams(term,n)
    return(generated_ngrams)

# %%
def language_ngrams(files):
    ngrams_list={}
    i=0
    for file in files:
        ngrams_list[i]=generate_ngram(file,3)
        i=i+1
    return(ngrams_list)

# %%
npt_files=[' '.join(f) for f in pt_files]

# %%
del(pt_files) #We now use nfr_files instead ==> release ressources!

# %%
start=time.time()
r=language_ngrams(npt_files)
end=time.time()
print(end-start)
# Out:
# 0.031248092651367188

# %%
start=time.time()
l=[]
for i in range(0,len(r)):
    l.append(list(r[i]))
end=time.time()
print(end-start)
# Out:
# 1.7343363761901855

# %%
del(r)

# %%
start=time.time()
for i in range (0,943):
    pt_trigrams=l[i*10:(i+1)*10]
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\portuguese\\"+'pt_trigrams'+str(i+1)
    with open (file_name,'wb') as pickle_out31:
        pickle.dump(pt_trigrams,pickle_out31)
    del(pickle_out31)
    del(pt_trigrams)
end=time.time()
print(end-start)
# Out:
# 3.2499213218688965

# %%
pt_trigrams=l[9430:9434]
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\portuguese\\pt_trigrams944"
with open (file_name,'wb') as pickle_out31:
    pickle.dump(pt_trigrams,pickle_out31)
del(pickle_out31)
del(pt_trigrams)

# %%
start=time.time()
final=[]
for i in range (0,944):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\portuguese\\"+'pt_trigrams'+str(i+1)
    with open(file_name,'rb') as pickle_in:
        final.append(frequency_dataframe(pickle.load(pickle_in)))
    del pickle_in
end=time.time()
print(end-start)
# Out:
# 4.531113862991333

# %%
start=time.time()
for i in range (0,944):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\pt_frequency\\"+'pt_frequency'+str(i+1)
    with open (file_name,'wb') as pickle_out32:
        pickle.dump(final[i],pickle_out32)
end=time.time()
print(end-start)
# Out:
# 0.07812118530273438

# %%
start=time.time()
final=[]
for i in range (0,944):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\pt_frequency\\"+'pt_frequency'+str(i+1)
    with open (file_name,'rb') as pickle_in332:
        final.append(pickle.load(pickle_in332))
    del(pickle_in332)
end=time.time()
print(end-start)
# Out:
# 6.624540090560913

# %%
def frequency_dataframe(trigram_file):
    h=[]
    for file in trigram_file:
        h.append(nltk.FreqDist(file))
    return(h)

# %%
def extract_max_trigrams(freq_dictt):
    new_dict={}
    for key in freq_dictt:
        if (freq_dictt[key]>=300):
            new_dict[key]=freq_dictt[key]
    return(sorted(new_dict.items(),key=operator.itemgetter(1)))

# %%
mn=[]
start=time.time()
for i in range (0,944):
    for dictio in final[i]:
        mn.append(extract_max_trigrams(dictio))
end=time.time()
print(end-start)
# Out:
# 1.7030303478240967

# %%
del(final) #Release ressources man!!

# %%
mnn=[]
start=time.time()
for i in range (0,len(mn)):
    if (len(mn[i])>100):
        mnn.append(mn[i])
end=time.time()
print(end-start)
# Out:
# 0.0

# %%
list_trigrams=[]
start=time.time()
for i in range (0,len(mnn)):
    for j in range (len(mnn[i])-100,len(mnn[i])):
        list_trigrams.append(mnn[i][j][0])
end=time.time()
print(end-start)
# Out:
# 0.03124690055847168

# %%
pt_features=set(list_trigrams)
print(len(list_trigrams))
print(len(pt_features))
print(pt_features)
# Out:
# 63500
# 306
# {('q', 'u', 'i'), ('c', 'a', ' '), ('s', 't', 'i'), ('i', 's', ' '), ('o', 'c', 'i'), ('i', 'd', 'e'), ('r', 'c', 'a'), ('o', ' ', 'a'), ('r', 'l', 'a'), ('s', ' ', 'd'), ('r', 'a', 'b'), ('t', 'r', 'a'), ('f', 'o', 'r'), ('a', 'm', 'e'), ('i', 'o', ' '), (' ', 'o', ' '), ('a', ' ', 'i'), ('u', 'n', 'i'), ('a', 'n', 'd'), ('o', 'r', 'm'), ('i', 'c', 'i'), ('e', 's', ' '), ('b', 'a', 'l'), ('u', 'r', 'o'), ('r', 'e', 'g'), ('r', 'a', ' '), (' ', 'p', 'a'), ('n', 'h', 'o'), ('e', 's', 'p'), ('a', ' ', 'u'), ('o', 'r', ' '), ('r', 'i', 'a'), ('o', ' ', 't'), ('v', 'i', 'c'), ('n', 'g', 'u'), ('r', 'v', 'i'), ('s', ' ', 'e'), ('t', 'a', 'r'), ('t', 'o', ' '), (' ', 'a', 's'), ('i', 'c', 'o'), ('m', 'e', 'n'), ('o', 'r', 't'), ('c', 'o', 'e'), ('e', ' ', 't'), ('r', 'g', 'a'), ('o', 'l', 'i'), ('e', 'c', 't'), ('a', 'i', 's'), (' ', 'e', 'n'), ('e', ' ', 'a'), ('r', 'o', 'p'), (' ', 'm', 'a'), (' ', 's', 'u'), ('r', 'a', 't'), ('s', 'p', 'e'), ('s', 'a', 'o'), ('n', 'c', 'i'), ('e', ' ', 'n'), ('s', 's', 'a'), ('t', 'e', 'r'), ('a', ' ', 't'), ('r', 'a', 'n'), ('d', 'e', 's'), (' ', 'd', 'o'), ('e', 'r', 'a'), (' ', 's', 'a'), ('a', 'r', 'i'), (' ', 'm', 'u'), ('u', 'l', 't'), ('i', 't', 'i'), ('a', 'n', 't'), ('s', ' ', 'c'), ('m', 'o', ' '), ('d', 'i', 'r'), ('r', 'o', 's'), (' ', 'e', 'u'), ('i', 'n', 'g'), (' ', 'e', ' '), ('n', 'a', ' '), ('p', 'o', 's'), (' ', 'p', ' '), ('s', 's', 'o'), ('n', 'c', 'a'), ('s', ' ', 'p'), (' ', 'r', 'e'), (' ', 's', 'o'), ('i', 't', 'o'), ('s', 't', 'e'), (' ', 'a', 'g'), ('a', 't', 'a'), ('e', 's', 'i'), ('q', 'u', 'e'), (' ', 'a', 'c'), ('h', 'e', 'r'), ('s', ' ', 'q'), (' ', 'p', 'o'), ('s', 's', 'i'), ('o', ' ', 'd'), ('g', 'i', 'o'), (' ', 'd', 'a'), ('p', 'o', 'r'), ('c', 'i', 'a'), ('p', 'r', 'e'), ('o', 'm', 'i'), (' ', 'u', 'm'), ('a', 'l', 'i'), ('e', ' ', 'o'), ('v', 'e', 's'), ('t', 'u', 'r'), ('r', 'q', 'u'), ('o', 'e', 's'), ('n', 't', 'e'), ('s', ' ', 's'), ('s', 'm', 'o'), ('h', 'u', 'n'), ('r', 'o', 'r'), (' ', 'n', 'a'), ('s', 't', 'r'), ('r', 'e', 'c'), ('i', 'm', 'i'), ('o', ' ', 'e'), ('e', 'g', 'i'), ('o', 'n', 't'), ('c', 'u', 'l'), ('l', 'h', 'e'), (' ', 'h', 'u'), ('a', 'c', 'o'), ('e', 'r', ' '), ('a', ' ', 'd'), ('i', 'c', 'a'), ('e', 'i', 'r'), (' ', 'm', 'o'), ('u', 'e', ' '), ('n', 'a', 'o'), ('e', 's', 't'), ('a', 'd', 'o'), ('i', 't', 'u'), ('a', ' ', 'n'), ('t', 'i', 't'), ('n', 'e', 'r'), ('d', 'o', ' '), ('a', 'r', ' '), ('e', ' ', 'd'), ('a', ' ', 'e'), ('e', 'l', 'a'), ('s', 'e', 'n'), ('o', ' ', 'n'), ('u', 'c', 'a'), ('s', 'o', 'c'), ('r', 'e', 's'), ('t', 'e', 'n'), ('i', 'd', 'o'), ('a', 'd', 'a'), (' ', 't', 'r'), (' ', 'e', 'm'), ('i', 's', 't'), ('a', 'l', 'h'), ('o', ' ', 'c'), (' ', 'a', 'l'), ('a', 'c', 'a'), ('o', 'p', 'e'), ('r', 'i', 's'), ('e', 'u', 'r'), ('e', 'n', 'c'), (' ', 'i', 'n'), ('l', 'i', 't'), ('e', ' ', 'm'), ('e', 'i', 't'), (' ', 'u', 'n'), ('a', ' ', 'p'), ('a', 'o', ' '), ('t', 'a', ' '), (' ', 'd', 'e'), ('i', 'd', 'a'), ('a', 'l', ' '), ('o', ' ', 'q'), ('c', 'a', 'o'), ('d', 'o', 's'), (' ', 't', 'u'), ('r', 'm', 'a'), ('a', ' ', 'c'), ('t', 'e', ' '), ('i', 'r', 'e'), ('g', 'i', 'a'), ('m', 'a', ' '), (' ', 'n', 'o'), ('s', 'e', ' '), ('u', 'r', 'q'), ('d', 'a', ' '), (' ', 'f', 'a'), ('e', 'm', 'p'), ('o', ' ', 'p'), ('e', 'm', ' '), ('u', 'm', 'a'), ('n', 's', 't'), ('m', 'a', 'i'), ('e', 'n', 'e'), ('a', 'm', 'b'), ('p', 'o', 'l'), ('e', ' ', 'p'), ('t', 'o', 's'), ('o', 'r', 'i'), ('e', 'r', 'e'), ('a', ' ', 'm'), ('s', 't', 'a'), ('a', 's', ' '), ('a', 'n', 'c'), ('d', 'a', 's'), ('m', 'u', 'l'), ('o', ' ', 's'), ('i', 'a', ' '), ('s', 'e', 's'), ('i', 'm', 'e'), (' ', 'c', 'u'), ('r', 'a', 'm'), ('n', 't', 'o'), ('d', 'e', 'n'), ('a', ' ', 's'), ('e', 'n', 'h'), ('s', 'o', ' '), ('e', ' ', 'e'), (' ', 'o', 'r'), ('e', 's', 'a'), ('e', ' ', 's'), ('r', 'e', 'l'), (' ', 'i', 'm'), ('g', 'o', ' '), ('m', 'i', 'g'), (' ', 'c', 'a'), (' ', 'e', 's'), ('s', ' ', 'a'), ('g', 'r', 'a'), ('o', 's', 't'), ('e', 'r', 'g'), ('n' ...

# %%
del(mn)
del(mnn) #Boy gotta clear those ressources! We don't need them anyway we got our french features vector.

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\pt_features"
with open (file_name,'wb') as pickle_out32:
    pickle.dump(pt_features,pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\pt_features"
with open (file_name,'rb') as pickle_out32:
    pt_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\it_features"
with open (file_name,'rb') as pickle_out32:
    it_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\fr_features"
with open (file_name,'rb') as pickle_out32:
    fr_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\sp_features"
with open (file_name,'rb') as pickle_out32:
    sp_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
c=0
ffr_features=[]
for i in fr_features:
    if (i not in it_features and i not in pt_features and i not in sp_features):
        c=c+1
        ffr_features.append(i)
print(c)
# Out:
# 286

# %%
d=0
fpt_features=[]
for i in pt_features:
    if (i not in it_features and i not in fr_features and i not in sp_features):
        d=d+1
        fpt_features.append(i)
print(d)
# Out:
# 57

# %%
e=0
fsp_features=[]
for i in sp_features:
    if (i not in it_features and i not in pt_features and i not in fr_features):
        e=e+1
        fsp_features.append(i)
print(e)
# Out:
# 51

# %%
f=0
fit_features=[]
for i in it_features:
    if (i not in fr_features and i not in pt_features and i not in sp_features):
        f=f+1
        fit_features.append(i)
print(f)
# Out:
# 70

# %%
df_dict={}
start=time.time()
for trigram in fsp_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 6.687040328979492

# %%
start=time.time()
for trigram in fit_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 9.124871492385864

# %%
start=time.time()
for trigram in fpt_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 8.9369056224823

# %%
start=time.time()
for trigram in ffr_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 35.74755024909973

# %%
del(final)

# %%
pt_dataFrame=pd.DataFrame.from_dict(df_dict)

# %%
pt_dataFrame
# Out:
#                                                                             \
#                        a
#              s         g         i         m         p         s         u
# 0     0.000563  0.000498  0.000249  0.000314  0.001441  0.002704  0.000367
# 1     0.000481  0.000455  0.000243  0.000385  0.001380  0.002519  0.000834
# 2     0.000472  0.000495  0.000224  0.000497  0.001066  0.002083  0.000222
# 3     0.000518  0.000325  0.000360  0.000328  0.001118  0.002404  0.000290
# 4     0.000602  0.000262  0.000170  0.000157  0.001191  0.002356  0.000222
# 5     0.000411  0.000483  0.000251  0.000511  0.001245  0.002098  0.000593
# 6     0.000553  0.000195  0.000215  0.000918  0.001471  0.002037  0.001327
# 7     0.000487  0.000517  0.000232  0.000435  0.001219  0.002960  0.000238
# 8     0.000516  0.000894  0.000255  0.000650  0.001171  0.002321  0.000414
# 9     0.000431  0.000525  0.000300  0.000435  0.001027  0.002386  0.000238
# 10    0.000451  0.000372  0.000213  0.000409  0.001116  0.002341  0.000451
# 11    0.000501  0.000222  0.000189  0.000211  0.000779  0.001869  0.000300
# 12    0.000373  0.000391  0.000309  0.000498  0.001020  0.002366  0.000224
# 13    0.000481  0.000335  0.000309  0.000541  0.001305  0.002687  0.000541
# 14    0.000378  0.000354  0.000313  0.000479  0.001170  0.001987  0.000276
# 15    0.000510  0.000421  0.000203  0.000801  0.001139  0.002111  0.000232
# 16    0.000486  0.000328  0.000235  0.000514  0.001216  0.002275  0.000501
# 17    0.000633  0.000316  0.000213  0.000378  0.001175  0.002382  0.000396
# 18    0.000542  0.001417  0.000184  0.000242  0.001463  0.003053  0.000265
# 19    0.000437  0.000482  0.000269  0.000578  0.001153  0.002376  0.000230
# 20    0.000485  0.000337  0.000221  0.000380  0.001037  0.002435  0.000294
