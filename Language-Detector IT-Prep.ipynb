# %%
import os #To manage access to directories from python
import string
import unicodedata
from nltk import ngrams
import pickle
import time
import pandas as pd
import nltk
import operator

# %%
start=time.time()
with open('final_dict','rb') as pickle_in:
    final_dict = pickle.load(pickle_in)
end=time.time()
print(end-start)
# Out:
# 18.813880681991577

# %%
it_files=final_dict['italian']

# %%
del(final_dict) #unbind to release memory

# %%
def generate_ngram(term,n):
    generated_ngrams = ngrams(term,n)
    return(generated_ngrams)

# %%
def language_ngrams(files):
    ngrams_list={}
    i=0
    for file in files:
        ngrams_list[i]=generate_ngram(file,3)
        i=i+1
    return(ngrams_list)

# %%
nit_files=[' '.join(f) for f in it_files]

# %%
del(it_files) #We now use nfr_files instead ==> release ressources!

# %%
start=time.time()
r=language_ngrams(nit_files)
end=time.time()
print(end-start)
# Out:
# 0.14714360237121582

# %%
start=time.time()
l=[]
for i in range(0,len(r)):
    l.append(list(r[i]))
end=time.time()
print(end-start)
# Out:
# 3902.076456308365

# %%
del(r)

# %%
start=time.time()
for i in range (0,948):
    it_trigrams=l[i*10:(i+1)*10]
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\italian\\"+'it_trigrams'+str(i+1)
    with open (file_name,'wb') as pickle_out31:
        pickle.dump(it_trigrams,pickle_out31)
    del(pickle_out31)
    del(it_trigrams)
end=time.time()
print(end-start)
# Out:
# 1975.1656975746155

# %%
it_trigrams=l[9480:9486]
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\italian\\it_trigrams949"
with open (file_name,'wb') as pickle_out31:
    pickle.dump(it_trigrams,pickle_out31)
del(pickle_out31)
del(it_trigrams)

# %%
start=time.time()
final=[]
for i in range (0,949):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\trigrams\\italian\\"+'it_trigrams'+str(i+1)
    with open(file_name,'rb') as pickle_in:
        final.append(frequency_dataframe(pickle.load(pickle_in)))
    del pickle_in
end=time.time()
print(end-start)
# Out:
# 542.2552664279938

# %%
start=time.time()
for i in range (0,949):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\it_frequency\\"+'it_frequency'+str(i+1)
    with open (file_name,'wb') as pickle_out32:
        pickle.dump(final[i],pickle_out32)
end=time.time()
print(end-start)
# Out:
# 17.095451831817627

# %%
start=time.time()
final=[]
for i in range (0,949):
    file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\it_frequency\\"+'it_frequency'+str(i+1)
    with open (file_name,'rb') as pickle_in332:
        final.append(pickle.load(pickle_in332))
    del(pickle_in332)
end=time.time()
print(end-start)
# Out:
# 14.56151294708252

# %%
def frequency_dataframe(trigram_file):
    h=[]
    for file in trigram_file:
        h.append(nltk.FreqDist(file))
    return(h)

# %%
def extract_max_trigrams(freq_dictt):
    new_dict={}
    for key in freq_dictt:
        if (freq_dictt[key]>=300):
            new_dict[key]=freq_dictt[key]
    return(sorted(new_dict.items(),key=operator.itemgetter(1)))

# %%
mn=[]
start=time.time()
for i in range (0,944):
    for dictio in final[i]:
        mn.append(extract_max_trigrams(dictio))
end=time.time()
print(end-start)
# Out:
# 1.9061357975006104

# %%
del(final) #Release ressources man!!

# %%
mnn=[]
start=time.time()
for i in range (0,len(mn)):
    if (len(mn[i])>100):
        mnn.append(mn[i])
end=time.time()
print(end-start)
# Out:
# 0.0

# %%
list_trigrams=[]
start=time.time()
for i in range (0,len(mnn)):
    for j in range (len(mnn[i])-100,len(mnn[i])):
        list_trigrams.append(mnn[i][j][0])
end=time.time()
print(end-start)
# Out:
# 0.046877384185791016

# %%
it_features=set(list_trigrams)
print(len(list_trigrams))
print(len(it_features))
print(it_features)
# Out:
# 65100
# 297
# {('c', 'h', 'e'), ('n', 'g', 'u'), (' ', 't', 'e'), ('p', 'o', 'r'), ('u', 'r', 'o'), ('r', 'm', 'a'), ('a', 'l', 'e'), ('g', 'r', 'a'), (' ', 'n', 'o'), ('m', 'm', 'i'), ('r', 'c', 'h'), (' ', 'v', 'o'), ('n', 'e', ' '), ('r', 'a', 't'), (' ', 's', 'i'), ('e', 'n', 'z'), ('c', 'e', 'r'), ('i', 'n', 'g'), (' ', 'l', 'i'), (' ', 's', 'p'), ('t', 'a', 'r'), (' ', 'd', 'e'), ('a', 'm', 'e'), ('h', 'e', ' '), ('p', 'r', 'o'), ('l', 'a', ' '), ('n', 'o', 'n'), (' ', 'd', 'i'), ('p', 'e', 'a'), (' ', 'f', 'a'), (' ', 'i', 'l'), (' ', 'c', 'o'), ('p', 'r', 'e'), ('e', ' ', 'd'), (' ', 'd', 'o'), ('n', 't', 'a'), ('m', 'o', ' '), ('i', ' ', 'd'), ('c', 'h', 'i'), ('e', 'n', 'e'), ('e', 'l', 'l'), ('e', 'r', 'r'), ('e', 'r', 'g'), ('o', 'n', 's'), ('a', ' ', 's'), ('e', 'r', 'a'), ('l', 'a', 'v'), ('o', 'c', 'c'), ('d', 'o', 'n'), ('c', 'i', 'o'), ('t', 'u', 'r'), ('e', ' ', 'i'), ('t', 'r', 'a'), ('m', 'a', ' '), ('b', 'i', 'l'), (' ', 'l', 'e'), ('o', 'n', 'i'), ('a', 'l', 'l'), ('r', 'i', 's'), ('t', 't', 'o'), ('i', ' ', 'i'), ('a', 'm', 'm'), ('e', 's', 't'), ('i', 'a', 'm'), ('a', 'n', 't'), ('e', 'r', 'e'), ('i', 'z', 'i'), ('i', 'd', 'e'), ('r', 'i', 'c'), ('r', 'r', 'o'), (' ', 'p', ' '), ('o', 'n', 'n'), ('o', 'r', 't'), ('i', 'o', 'n'), (' ', 's', 'e'), ('a', ' ', 'd'), ('i', 'm', 'm'), ('n', 'a', ' '), ('r', 'e', 's'), ('p', 'a', 'r'), ('d', 'i', ' '), ('r', 'o', ' '), ('o', 'l', 'i'), ('i', 'l', ' '), (' ', 'l', 'a'), ('o', 's', 't'), ('a', 'z', 'i'), ('l', ' ', 'c'), ('s', 'e', ' '), ('n', 'o', ' '), ('e', 'l', ' '), ('i', 'n', 'a'), (' ', 'd', 'a'), ('i', ' ', 'l'), ('u', 'r', 'a'), ('s', 'i', 'o'), ('m', 'e', 'n'), ('i', 'l', 'i'), ('e', ' ', 'l'), (' ', 'a', 'n'), ('r', 'a', 'n'), ('l', 'a', 'r'), (' ', 'r', 'i'), ('p', 'o', 's'), ('n', 'i', ' '), ('e', 't', 't'), ('n', 'c', 'i'), ('r', 'a', 'm'), ('s', 'p', 'e'), ('n', 't', 'e'), (' ', 'm', 'o'), ('o', ' ', 'p'), ('t', 'o', ' '), ('n', 'e', 'r'), ('a', ' ', 'r'), (' ', 'c', 'a'), ('a', ' ', 'c'), ('n', 'z', 'a'), ('t', 'e', 'r'), ('i', 's', 's'), ('i', 's', 't'), ('c', 'o', 'l'), (' ', 'c', 'h'), (' ', 'e', ' '), ('s', 't', 'a'), ('i', 't', 'u'), ('r', 'i', ' '), ('n', 't', 'o'), ('r', 'e', 'g'), ('o', 'p', 'e'), ('s', 'i', ' '), ('n', 'e', 'l'), (' ', 'q', 'u'), ('s', 'e', 'r'), ('r', 'a', 'z'), ('e', ' ', 'r'), ('e', 'n', 't'), (' ', 'r', 'e'), ('a', 't', 'i'), ('q', 'u', 'e'), ('d', 'e', 'n'), (' ', 'a', ' '), ('o', 'm', 'm'), ('i', ' ', 'r'), ('a', 'r', 'e'), ('e', 'g', 'i'), ('a', 't', 'o'), ('e', 'i', ' '), ('i', 'c', 'o'), ('z', 'a', ' '), ('t', 't', 'a'), ('l', 'a', 'n'), ('a', ' ', 'a'), (' ', 'e', 'u'), ('d', 'e', 'l'), ('u', 'n', 'i'), ('l', 'i', 'n'), ('t', 'a', 't'), (' ', 'p', 'r'), (' ', 'b', 'i'), (' ', 'p', 'a'), ('c', 'o', 'n'), (' ', 'c', 'u'), ('r', 'e', ' '), ('t', 'e', ' '), ('i', 'o', ' '), ('m', 'i', 'g'), ('u', 'n', ' '), ('g', 'h', 'e'), ('r', 'i', 't'), ('i', 't', 'a'), ('r', 'l', 'a'), ('n', 'z', 'i'), ('e', 's', 's'), ('t', 'o', 'r'), ('o', ' ', 'i'), ('h', 'i', 'a'), ('l', 'i', ' '), ('o', 'r', 'i'), ('l', 'l', 'a'), ('i', ' ', 'e'), ('e', ' ', 'n'), ('i', 'a', ' '), ('o', ' ', 'e'), ('r', 'o', 'p'), ('c', 'o', 'm'), ('d', 'o', ' '), ('e', 'r', 'c'), ('c', 'a', ' '), ('s', 'o', 's'), ('v', 'o', 'r'), ('f', 'o', 'r'), ('e', ' ', 'e'), (' ', 'a', 'l'), ('o', 'n', 't'), ('a', 't', 't'), (' ', 'g', 'l'), (' ', 'm', 'a'), ('a', 'r', 'i'), ('o', ' ', 'd'), ('i', 'l', 'a'), ('i', 'n', ' '), ('a', 'n', 'c'), ('l', 'o', ' '), ('e', 'r', 'v'), ('h', 'e', 'r'), (' ', 's', 'u'), ('a', ' ', 'p'), ('e', 't', 'i'), ('t', 'i', ' '), ('o', ' ', 'c'), ('a', 'm', 'o'), (' ', 'e', 's'), ('t', 't', 'i'), (' ', 'e', 'n'), ('u', 'n', 'g'), ('n', 't', 'i'), ('s', 'o', 'c'), ('i', 'm', 'p'), ('s', 't', 'i'), (' ', 'n', 'e'), ('i', 'e', 'n'), ('g', 'i', 'o'), ('a', ' ', 'l'), ('i', 'c', 'e'), ('i', 'c', 'a'), ('t', 'i', 'v'), ('c', 'o', 's'), (' ', 'p', 'e'), ('e', 's', 'i'), ('p', 'e', 'r'), ('a', 'l', 'i'), ('r', 'a', ' '), ('o', ' ', 's'), ('e', ' ', 'a'), ('g' ...

# %%
del(mn)
del(mnn) #Boy gotta clear those ressources! We don't need them anyway we got our french features vector.

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\it_features"
with open (file_name,'wb') as pickle_out32:
    pickle.dump(it_features,pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\it_features"
with open (file_name,'rb') as pickle_out32:
    it_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\fr_features"
with open (file_name,'rb') as pickle_out32:
    fr_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\sp_features"
with open (file_name,'rb') as pickle_out32:
    sp_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
file_name="C:\\Users\\YsfDS\\Documents\\AI Project\\features\\pt_features"
with open (file_name,'rb') as pickle_out32:
    pt_features=pickle.load(pickle_out32)
del(pickle_out32)

# %%
c=0
ffr_features=[]
for i in fr_features:
    if (i not in it_features and i not in pt_features and i not in sp_features):
        c=c+1
        ffr_features.append(i)
print(c)
# Out:
# 286

# %%
d=0
fpt_features=[]
for i in pt_features:
    if (i not in it_features and i not in fr_features and i not in sp_features):
        d=d+1
        fpt_features.append(i)
print(d)
# Out:
# 57

# %%
e=0
fsp_features=[]
for i in sp_features:
    if (i not in it_features and i not in pt_features and i not in fr_features):
        e=e+1
        fsp_features.append(i)
print(e)
# Out:
# 51

# %%
f=0
fit_features=[]
for i in it_features:
    if (i not in fr_features and i not in pt_features and i not in sp_features):
        f=f+1
        fit_features.append(i)
print(f)
# Out:
# 70

# %%
df_dict={}
start=time.time()
for trigram in fsp_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 7.452630519866943

# %%
start=time.time()
for trigram in fit_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 13.952150106430054

# %%
start=time.time()
for trigram in fpt_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 10.76488184928894

# %%
start=time.time()
for trigram in ffr_features:
    temp=[]
    for i in range (0,len(final)):
        for j in range (0,len(final[i])):
            if final[i][j][trigram]:
                temp.append(final[i][j][trigram]/sum(list(final[i][j].values())))
            else: 
                temp.append(0)
    df_dict[trigram]=temp
end=time.time()
print(end-start)
# Out:
# 41.26329231262207

# %%
del(final)

# %%
it_dataFrame=pd.DataFrame.from_dict(df_dict)

# %%
it_dataFrame
# Out:
#                                                                             \
#                        a
#              s         g         i         m         p         s         u
# 0     0.000555  0.000379  0.000379  0.000294  0.000666  0.000503  0.000327
# 1     0.000470  0.000351  0.000707  0.000480  0.000620  0.000603  0.000501
# 2     0.000470  0.000317  0.000299  0.000493  0.000503  0.000649  0.000246
# 3     0.000508  0.000279  0.000391  0.000307  0.000603  0.000419  0.000290
# 4     0.000593  0.000342  0.000593  0.000329  0.000566  0.000764  0.000263
# 5     0.000414  0.000234  0.000373  0.000556  0.000661  0.000490  0.000683
# 6     0.000552  0.000197  0.000401  0.000729  0.000703  0.000552  0.001347
# 7     0.000472  0.000489  0.000343  0.000545  0.000494  0.000668  0.000388
# 8     0.000509  0.000368  0.000296  0.000620  0.000564  0.000524  0.000361
# 9     0.000427  0.000304  0.000445  0.000434  0.000493  0.000661  0.000295
# 10    0.000462  0.000350  0.000360  0.000383  0.000541  0.000585  0.000355
# 11    0.000488  0.000188  0.000366  0.000244  0.000532  0.000421  0.000299
# 12    0.000372  0.000241  0.000339  0.000515  0.000477  0.000559  0.000283
# 13    0.000478  0.000273  0.000512  0.000418  0.000717  0.000640  0.000376
# 14    0.000375  0.000198  0.000335  0.000415  0.000443  0.000431  0.000310
# 15    0.000501  0.000328  0.000402  0.000621  0.000508  0.000426  0.000236
# 16    0.000487  0.000270  0.000439  0.000427  0.000582  0.000527  0.000472
# 17    0.000621  0.000198  0.000471  0.000345  0.000608  0.000547  0.000319
# 18    0.000516  0.001201  0.000718  0.000483  0.000797  0.000662  0.000438
# 19    0.000441  0.000386  0.000419  0.000524  0.000606  0.000583  0.000254
# 20    0.000481  0.000371  0.000408  0.000499  0.000585  0.000597  0.000347
# 21    0.000498  0.000360  0.000350  0.000291  0.000601  0.000621  0.000384
# 22    0.000439  0.000366  0.000411  0.000381  0.000559  0.000587  0.000275
